# %%
# %load_ext autoreload
# %autoreload 2

# %%
import opticalrs as ors
from opticalrs.WorldView import WorldViewObj

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
wv = WorldViewObj('/home/jkibele/repos/OpticalRS/tests/input_data/eReefWV2.tif')

# %%
rgb = wv.ocean_equalized_rgb()
imshow(rgb)

# %%
masked = wv.mask_land()

# %%
imshow(masked[..., 0].mask)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-d1fe264a2493> in <module>
# ----> 1 wv.band_array.mask
#
# AttributeError: 'numpy.ndarray' object has no attribute 'mask'
